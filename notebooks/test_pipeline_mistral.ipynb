# %%
import ast
import json
import os
import pandas as pd
from tqdm import tqdm
from mibi.modules import DocumentsModule, Question
from test_utils import (
    get_snippets,
    PubMedApiRetrieve,
    rerank_biencoder,
    rerank_crossencoder,
    get_snippets,
    get_offset,
    response_exact_answer,
    response_ideal_answer,
    flat_list,
    get_snippets_blablador,
    retrieve_bm25,
    response_exact_answer_mistral,
    response_ideal_answer_mistral,
)

# %% [markdown]
# ### Blablador Mistral API for snippets

# %%
IN_DIR = "temp/reranked/"

for file in tqdm(os.listdir(IN_DIR)):
    reranked = pd.read_csv(os.path.join(IN_DIR, file))
    reranked["snippets_blablador_mistral"] = reranked.apply(
        lambda x: get_snippets_blablador(
            x["question"], x["title"], x["text"], model="Mistral-7B-Instruct-v0.2"
        ),
        axis=1,
    )

    reranked["title_snippets_mistral"] = [
        x[0] for x in reranked["snippets_blablador_mistral"]
    ]
    reranked["abstract_snippets_mistral"] = [
        x[1] for x in reranked["snippets_blablador_mistral"]
    ]

    reranked["offset_title_mistral"] = reranked.apply(
        lambda x: get_offset(x["title_snippets_mistral"], x["text"]), axis=1
    )
    reranked["offset_abstract_mistral"] = reranked.apply(
        lambda x: get_offset(x["abstract_snippets_mistral"], x["text"]), axis=1
    )

    reranked.to_csv(f"temp/snippets/mistral/{file}", index=False)
# Out:
# 100%|██████████| 5/5 [05:23<00:00, 64.65s/it]

# %%
IN_DIR = "temp/snippets/mistral/"

for file in tqdm(os.listdir(IN_DIR)):
    if "54e25eaaae9738404b000017" in file:
        reranked = pd.read_csv(os.path.join(IN_DIR, file))

        reranked["answer_snippets_exact_mistral"] = [
            response_exact_answer_mistral(
                reranked["question"].tolist()[0],
                reranked["questiontype"].tolist()[0],
                "".join(
                    reranked["abstract_snippets_mistral"].tolist()
                    + reranked["title_snippets_mistral"]
                ),
                model="Mistral-7B-Instruct-v0.2",
            )
        ] * len(reranked)

        reranked["answer_snippets_ideal_mistral"] = [
            response_ideal_answer_mistral(
                reranked["question"].tolist()[0],
                reranked["questiontype"].tolist()[0],
                "".join(
                    flat_list(reranked["abstract_snippets_mistral"].tolist())
                    + flat_list(reranked["title_snippets_mistral"])
                ),
                model="Mistral-7B-Instruct-v0.2",
            )
        ] * len(reranked)

#
# Out:
# 100%|██████████| 5/5 [00:01<00:00,  2.97it/s]

# %%
reranked
# Out:
#       docno  score  rank                                              title  \
# 0  15094122      0    15  Papilin, a novel component of basement membran...
# 1  11076767      0    18  Papilin in development; a pericellular protein...
# 2  12666201      0    17  Alternative splicing of papilin and the divers...
# 3  38284126      0     1  Secreted ADAMTS-like proteins as regulators of...
# 4  32585132      0     5  Comprehensive Endogenous Tagging of Basement M...
# 5  20805556      0    13  Genetics of extracellular matrix remodeling du...
# 6  15094110      0    16      The thrombospondin type 1 repeat superfamily.
# 7  34240827      0     3  Primary angle closure glaucoma is characterize...
# 8  19297413      0    14  C. elegans mig-6 encodes papilin isoforms that...
# 9   7515725      0    19  Differentiation, extracellular matrix synthesi...
#
#                                                 text  \
# 0  Papilins are homologous, secreted extracellula...
# 1  Papilin is an extracellular matrix glycoprotei...
# 2  Papilins are extracellular matrix proteins tha...
# 3  The extracellular matrix (ECM) determines func...
# 4  Basement membranes (BMs) are supramolecular ma...
# 5  The organs of animal embryos are typically cov...
# 6  The TSR superfamily is a diverse family of ext...
# 7  To characterize the proteome of the iris in pr...
# 8  The gonad arms of C. elegans hermaphrodites ac...
# 9  Two contrasting substrates, Drosophila laminin...
#
#                                          url  bm25   cos_sim  \
# 0  https://pubmed.ncbi.nlm.nih.gov/15094122/   0.0  0.628675
# 1  https://pubmed.ncbi.nlm.nih.gov/11076767/   0.0  0.587269
# 2  https://pubmed.ncbi.nlm.nih.gov/12666201/   0.0  0.515122
# 3  https://pubmed.ncbi.nlm.nih.gov/38284126/   0.0  0.411736
# 4  https://pubmed.ncbi.nlm.nih.gov/32585132/   0.0  0.403068
# 5  https://pubmed.ncbi.nlm.nih.gov/20805556/   0.0  0.397381
# 6  https://pubmed.ncbi.nlm.nih.gov/15094110/   0.0  0.364708
# 7  https://pubmed.ncbi.nlm.nih.gov/34240827/   0.0  0.360284
# 8  https://pubmed.ncbi.nlm.nih.gov/19297413/   0.0  0.333149
# 9   https://pubmed.ncbi.nlm.nih.gov/7515725/   0.0  0.330635
#
#                            question                questionno questiontype  \
# 0  Is the protein Papilin secreted?  54e25eaaae9738404b000017        yesno
# 1  Is the protein Papilin secreted?  54e25eaaae9738404b000017        yesno
# 2  Is the protein Papilin secreted?  54e25eaaae9738404b000017        yesno
# 3  Is the protein Papilin secreted?  54e25eaaae9738404b000017        yesno
# 4  Is the protein Papilin secreted?  54e25eaaae9738404b000017        yesno
# 5  Is the protein Papilin secreted?  54e25eaaae9738404b000017        yesno
# 6  Is the protein Papilin secreted?  54e25eaaae9738404b000017        yesno
# 7  Is the protein Papilin secreted?  54e25eaaae9738404b000017        yesno
# 8  Is the protein Papilin secreted?  54e25eaaae9738404b000017        yesno
# 9  Is the protein Papilin secreted?  54e25eaaae9738404b000017        yesno
#
#                           snippets_blablador_mistral  \
# 0  (['Papilin, a novel component of basement memb...
# 1  (['Papilin in development; a pericellular prot...
# 2  (['Alternative splicing of papilin and the div...
# 3  ([], ['The secreted a disintegrin and metallop...
# 4  ([], ['Through photobleaching studies, we show...
# 5  (['The organs of animal embryos are typically ...
# 6  (['The thrombospondin type 1 repeat superfamil...
# 7  (['Primary angle closure glaucoma is character...
# 8  (['C. elegans mig-6 encodes papilin isoforms t...
# 9  ([], ['Collagen IV, laminin, glutactin, papili...
#
#                               title_snippets_mistral  \
# 0  ['Papilin, a novel component of basement membr...
# 1  ['Papilin in development; a pericellular prote...
# 2  ['Alternative splicing of papilin and the dive...
# 3                                                 []
# 4                                                 []
# 5  ['The organs of animal embryos are typically c...
# 6  ['The thrombospondin type 1 repeat superfamily.']
# 7  ['Primary angle closure glaucoma is characteri...
# 8  ['C. elegans mig-6 encodes papilin isoforms th...
# 9                                                 []
#
#                            abstract_snippets_mistral  \
# 0  ['They occur widely, from nematodes to man," "...
# 1  ['Determination of its cDNA sequence led to th...
# 2  ['Papilins are extracellular matrix proteins t...
# 3  ['The secreted a disintegrin and metalloprotei...
# 4  ['Through photobleaching studies, we show that...
# 5  ['We previously described the twisting of the ...
# 6  ['Many of which have functions related to regu...
# 7  ['The main outcome was proteins with a log2 fo...
# 8  ['The gonad arms of C. elegans hermaphrodites ...
# 9  ['Collagen IV, laminin, glutactin, papilin, an...
#
#            offset_title_mistral  \
# 0                          [()]
# 1                          [()]
# 2                          [()]
# 3                            []
# 4                            []
# 5  [(), (), (), (), (725, 843)]
# 6                          [()]
# 7                          [()]
# 8                          [()]
# 9                            []
#
#                              offset_abstract_mistral  \
# 0                                               [()]
# 1  [(273, 375), (376, 556), (685, 784), (785, 901...
# 2     [(0, 109), (286, 441), (442, 507), (508, 768)]
# 3                                   [(), (584, 671)]
# 4                                       [(477, 626)]
# 5             [(), (), (), (725, 843), (1116, 1415)]
# 6                                               [()]
# 7                                           [(), ()]
# 8  [(), (), (394, 539), (540, 713), (714, 835), (...
# 9                                       [(732, 881)]
#
#   answer_snippets_exact_mistral  \
# 0                          Yes.
# 1                          Yes.
# 2                          Yes.
# 3                          Yes.
# 4                          Yes.
# 5                          Yes.
# 6                          Yes.
# 7                          Yes.
# 8                          Yes.
# 9                          Yes.
#
#                        answer_snippets_ideal_mistral
# 0   Yes, papilin is a secreted extracellular matr...
# 1   Yes, papilin is a secreted extracellular matr...
# 2   Yes, papilin is a secreted extracellular matr...
# 3   Yes, papilin is a secreted extracellular matr...
# 4   Yes, papilin is a secreted extracellular matr...
# 5   Yes, papilin is a secreted extracellular matr...
# 6   Yes, papilin is a secreted extracellular matr...
# 7   Yes, papilin is a secreted extracellular matr...
# 8   Yes, papilin is a secreted extracellular matr...
# 9   Yes, papilin is a secreted extracellular matr...

# %%
reranked

# %%
# reranked["answer_abstracts_exact"] = [
#     response_exact_answer(
#         question.body,
#         question.type,
#         " ".join(reranked["text"].tolist()[:ABSTRACTS_FOR_ANSWER]),
#     )
# ] * len(reranked)
# reranked["answer_abstracts_ideal"] = [
#     response_ideal_answer(
#         question.body,
#         question.type,
#         " ".join(reranked["text"].tolist()[:ABSTRACTS_FOR_ANSWER]),
#     )
# ] * len(reranked)
# reranked["answer_snippets_exact"] = [
#     response_exact_answer(
#         question.body,
#         question.type,
#         " ".join(
#             flat_list(reranked["abstract_snippets"].tolist())
#             + flat_list(reranked["title_snippets"])
#         ),
#     )
# ] * len(reranked)
# reranked["answer_snippets_ideal"] = [
#     response_ideal_answer(
#         question.body,
#         question.type,
#         " ".join(
#             flat_list(reranked["abstract_snippets"].tolist())
#             + flat_list(reranked["title_snippets"])
#         ),
#     )
# ] * len(reranked)
